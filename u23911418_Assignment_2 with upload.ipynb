# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
import numpy as np

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Display the shape of training and testing datasets
print(f"Training images shape: {train_images.shape}")
print(f"Training labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Test labels shape: {test_labels.shape}")
# Out:
# Training images shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 1)
# Test images shape: (10000, 32, 32, 3)
# Test labels shape: (10000, 1)

# %%
if train_images is not None and train_labels is not None and test_images is not None and test_labels is not None:
    print("CIFAR-10 dataset loaded successfully.")
else:
    print("Failed to load CIFAR-10 dataset.")
# Out:
# CIFAR-10 dataset loaded successfully.

# %%
# Normalize: Scale pixel values to the range [0, 1]
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# Display a message confirming normalization
print("CIFAR-10 dataset normalized successfully.")
# Out:
# CIFAR-10 dataset normalized successfully.

# %%
# Reshape: Reshape the images to fit the LSTM model's input requirements
# Typically, LSTMs expect input in the form (samples, time steps, features)
train_images = train_images.reshape((train_images.shape[0], -1, 32 * 3))
test_images = test_images.reshape((test_images.shape[0], -1, 32 * 3))

# Display a message confirming reshaping
print("CIFAR-10 dataset reshaped for LSTM input successfully.")
# Out:
# CIFAR-10 dataset reshaped for LSTM input successfully.

# %%
# Define the encoder part of the autoencoder using LSTM layers
latent_dim = 128

define_input = layers.Input(shape=(train_images.shape[1], train_images.shape[2]))
encoded = layers.LSTM(256, activation='relu', return_sequences=True)(define_input)
encoded = layers.LSTM(latent_dim, activation='relu', return_sequences=False)(encoded)

# Create the encoder model
encoder = models.Model(define_input, encoded)

# Display a message confirming the encoder definition
print("Encoder model defined successfully.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 # Define the encoder part of the autoencoder using LSTM layers
#       2 latent_dim = 128
# ----> 4 define_input = layers.Input(shape=(train_images.shape[1], train_images.shape[2]))
#       5 encoded = layers.LSTM(256, activation='relu', return_sequences=True)(define_input)
#       6 encoded = layers.LSTM(latent_dim, activation='relu', return_sequences=False)(encoded)
#
# NameError: name 'layers' is not defined

# %%
from tensorflow.keras import layers, models

# %%
# Define the encoder part of the autoencoder using LSTM layers
latent_dim = 128

define_input = layers.Input(shape=(train_images.shape[1], train_images.shape[2]))
encoded = layers.LSTM(256, activation='relu', return_sequences=True)(define_input)
encoded = layers.LSTM(latent_dim, activation='relu', return_sequences=False)(encoded)

# Create the encoder model
encoder = models.Model(define_input, encoded)

# Display a message confirming the encoder definition
print("Encoder model defined successfully.")
# Out:
# Encoder model defined successfully.

# %%
# Define the decoder part of the autoencoder using LSTM layers
decoder_input = layers.RepeatVector(train_images.shape[1])(encoded)
decoded = layers.LSTM(256, activation='relu', return_sequences=True)(decoder_input)
decoded = layers.LSTM(train_images.shape[2], activation='sigmoid', return_sequences=True)(decoded)

# Create the autoencoder model
autoencoder = models.Model(input_layer, decoded)

# Display a message confirming the decoder definition
print("Decoder model defined successfully.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 7
#       4 decoded = layers.LSTM(train_images.shape[2], activation='sigmoid', return_sequences=True)(decoded)
#       6 # Create the autoencoder model
# ----> 7 autoencoder = models.Model(input_layer, decoded)
#       9 # Display a message confirming the decoder definition
#      10 print("Decoder model defined successfully.")
#
# NameError: name 'input_layer' is not defined

# %%
# Define the decoder part of the autoencoder using LSTM layers
decoder_input = layers.RepeatVector(train_images.shape[1])(encoded)
decoded = layers.LSTM(256, activation='relu', return_sequences=True)(decoder_input)
decoded = layers.LSTM(train_images.shape[2], activation='sigmoid', return_sequences=True)(decoded)

# Create the autoencoder model
autoencoder = models.Model(input_layer, decoded)

# Display a message confirming the decoder definition
print("Autoencoder model defined successfully.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 7
#       4 decoded = layers.LSTM(train_images.shape[2], activation='sigmoid', return_sequences=True)(decoded)
#       6 # Create the autoencoder model
# ----> 7 autoencoder = models.Model(input_layer, decoded)
#       9 # Display a message confirming the decoder definition
#      10 print("Autoencoder model defined successfully.")
#
# NameError: name 'input_layer' is not defined

# %%
# Define the decoder part of the autoencoder using LSTM layers
decoder_input_layer = layers.Input(shape=(latent_dim,))
decoder_input = layers.RepeatVector(train_images.shape[1])(decoder_input_layer)
decoded = layers.LSTM(256, activation='relu', return_sequences=True)(decoder_input)
decoded = layers.LSTM(train_images.shape[2], activation='sigmoid', return_sequences=True)(decoded)

# Create the autoencoder model
autoencoder = models.Model(input_layer, decoded)

# Display a message confirming the autoencoder definition
print("Autoencoder model defined successfully.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 8
#       5 decoded = layers.LSTM(train_images.shape[2], activation='sigmoid', return_sequences=True)(decoded)
#       7 # Create the autoencoder model
# ----> 8 autoencoder = models.Model(input_layer, decoded)
#      10 # Display a message confirming the autoencoder definition
#      11 print("Autoencoder model defined successfully.")
#
# NameError: name 'input_layer' is not defined

# %%
# Define the decoder part of the autoencoder using LSTM layers
decoder_input_layer = layers.Input(shape=(latent_dim,))
decoder_input = layers.RepeatVector(train_images.shape[1])(decoder_input_layer)
decoded = layers.LSTM(256, activation='relu', return_sequences=True)(decoder_input)
decoded = layers.LSTM(train_images.shape[2], activation='sigmoid', return_sequences=True)(decoded)

# Create the autoencoder model
autoencoder = models.Model(input_layer, decoded)

# Display a message confirming the autoencoder definition
print("Autoencoder model defined successfully.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 8
#       5 decoded = layers.LSTM(train_images.shape[2], activation='sigmoid', return_sequences=True)(decoded)
#       7 # Create the autoencoder model
# ----> 8 autoencoder = models.Model(input_layer, decoded)
#      10 # Display a message confirming the autoencoder definition
#      11 print("Autoencoder model defined successfully.")
#
# NameError: name 'input_layer' is not defined

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import layers, models
import numpy as np

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Display the shape of training and testing datasets
print(f"Training images shape: {train_images.shape}")
print(f"Training labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Test labels shape: {test_labels.shape}")

# Verify that the dataset has been loaded successfully
if train_images is not None and train_labels is not None and test_images is not None and test_labels is not None:
    print("CIFAR-10 dataset loaded successfully.")
else:
    print("Failed to load CIFAR-10 dataset.")

# Normalize: Scale pixel values to the range [0, 1]
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# Display a message confirming normalization
print("CIFAR-10 dataset normalized successfully.")

# Reshape: Reshape the images to fit the LSTM model's input requirements
# Typically, LSTMs expect input in the form (samples, time steps, features)
train_images = train_images.reshape((train_images.shape[0], -1, 32 * 3))
test_images = test_images.reshape((test_images.shape[0], -1, 32 * 3))

# Display a message confirming reshaping
print("CIFAR-10 dataset reshaped for LSTM input successfully.")

# Define the encoder part of the autoencoder using LSTM layers
latent_dim = 128

input_layer = layers.Input(shape=(train_images.shape[1], train_images.shape[2]))
encoded = layers.LSTM(256, activation='relu', return_sequences=True)(input_layer)
encoded = layers.LSTM(latent_dim, activation='relu', return_sequences=False)(encoded)

# Create the encoder model
encoder = models.Model(input_layer, encoded)

# Display a message confirming the encoder definition
print("Encoder model defined successfully.")

# Define the decoder part of the autoencoder using LSTM layers
decoder_input_layer = layers.Input(shape=(latent_dim,))
decoder_input = layers.RepeatVector(train_images.shape[1])(decoder_input_layer)
decoded = layers.LSTM(256, activation='relu', return_sequences=True)(decoder_input)
decoded = layers.LSTM(train_images.shape[2], activation='sigmoid', return_sequences=True)(decoded)

# Create the autoencoder model
autoencoder = models.Model(input_layer, decoded)

# Display a message confirming the autoencoder definition
print("Autoencoder model defined successfully.")
# Out:
# Training images shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 1)
# Test images shape: (10000, 32, 32, 3)
# Test labels shape: (10000, 1)
# CIFAR-10 dataset loaded successfully.
# CIFAR-10 dataset normalized successfully.
# CIFAR-10 dataset reshaped for LSTM input successfully.
# Encoder model defined successfully.
# Autoencoder model defined successfully.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import layers, models
import numpy as np

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Display the shape of training and testing datasets
print(f"Training images shape: {train_images.shape}")
print(f"Training labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Test labels shape: {test_labels.shape}")

# Verify that the dataset has been loaded successfully
if train_images is not None and train_labels is not None and test_images is not None and test_labels is not None:
    print("CIFAR-10 dataset loaded successfully.")
else:
    print("Failed to load CIFAR-10 dataset.")

# Normalize: Scale pixel values to the range [0, 1]
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# Display a message confirming normalization
print("CIFAR-10 dataset normalized successfully.")

# Reshape: Reshape the images to fit the LSTM model's input requirements
# Typically, LSTMs expect input in the form (samples, time steps, features)
train_images = train_images.reshape((train_images.shape[0], -1, 32 * 3))
test_images = test_images.reshape((test_images.shape[0], -1, 32 * 3))

# Display a message confirming reshaping
print("CIFAR-10 dataset reshaped for LSTM input successfully.")

# Define the encoder part of the autoencoder using LSTM layers
latent_dim = 128

input_layer = layers.Input(shape=(train_images.shape[1], train_images.shape[2]))
encoded = layers.LSTM(256, activation='relu', return_sequences=True)(input_layer)
encoded = layers.LSTM(latent_dim, activation='relu', return_sequences=False)(encoded)

# Create the encoder model
encoder = models.Model(input_layer, encoded)

# Display a message confirming the encoder definition
print("Encoder model defined successfully.")

# Define the decoder part of the autoencoder using LSTM layers
decoder_input_layer = layers.Input(shape=(latent_dim,))
decoder_input = layers.RepeatVector(train_images.shape[1])(decoder_input_layer)
decoded = layers.LSTM(256, activation='relu', return_sequences=True)(decoder_input)
decoded = layers.LSTM(train_images.shape[2], activation='sigmoid', return_sequences=True)(decoded)

# Create the autoencoder model
autoencoder = models.Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Display a message confirming the autoencoder compilation
print("Autoencoder model compiled successfully.")
# Out:
# Training images shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 1)
# Test images shape: (10000, 32, 32, 3)
# Test labels shape: (10000, 1)
# CIFAR-10 dataset loaded successfully.
# CIFAR-10 dataset normalized successfully.
# CIFAR-10 dataset reshaped for LSTM input successfully.
# Encoder model defined successfully.
# Autoencoder model compiled successfully.

# %%
# Train: Fit the model on distorted images as input and clear images as target output
# Here we simulate distorted images by adding random noise to the training images
noise_factor = 0.5
train_images_noisy = train_images + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=train_images.shape)
train_images_noisy = np.clip(train_images_noisy, 0., 1.)

# Train the autoencoder
history = autoencoder.fit(train_images_noisy, train_images, epochs=10, batch_size=64, validation_data=(test_images, test_images))

# Verify that the model has been trained successfully
if history.history['loss']:
    print("Autoencoder model trained successfully.")
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 8
#       5 train_images_noisy = np.clip(train_images_noisy, 0., 1.)
#       7 # Train the autoencoder
# ----> 8 history = autoencoder.fit(train_images_noisy, train_images, epochs=10, batch_size=64, validation_data=(test_images, test_images))
#      10 # Verify that the model has been trained successfully
#      11 if history.history['loss']:
#
# File /opt/anaconda3/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ...

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import layers, models
import numpy as np

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Display the shape of training and testing datasets
print(f"Training images shape: {train_images.shape}")
print(f"Training labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Test labels shape: {test_labels.shape}")

# Verify that the dataset has been loaded successfully
if train_images is not None and train_labels is not None and test_images is not None and test_labels is not None:
    print("CIFAR-10 dataset loaded successfully.")
else:
    print("Failed to load CIFAR-10 dataset.")

# Normalize: Scale pixel values to the range [0, 1]
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# Display a message confirming normalization
print("CIFAR-10 dataset normalized successfully.")

# Reshape: Reshape the images to fit the LSTM model's input requirements
# Typically, LSTMs expect input in the form (samples, time steps, features)
train_images = train_images.reshape((train_images.shape[0], -1, 32 * 3))
test_images = test_images.reshape((test_images.shape[0], -1, 32 * 3))

# Display a message confirming reshaping
print("CIFAR-10 dataset reshaped for LSTM input successfully.")

# Define the encoder part of the autoencoder using LSTM layers
latent_dim = 128

input_layer = layers.Input(shape=(train_images.shape[1], train_images.shape[2]))
encoded = layers.LSTM(256, activation='relu', return_sequences=True)(input_layer)
encoded = layers.LSTM(latent_dim, activation='relu', return_sequences=False)(encoded)

# Create the encoder model
encoder = models.Model(input_layer, encoded)

# Display a message confirming the encoder definition
print("Encoder model defined successfully.")

# Define the decoder part of the autoencoder using LSTM layers
decoder_input_layer = layers.Input(shape=(latent_dim,))
decoder_input = layers.RepeatVector(train_images.shape[1])(decoder_input_layer)
decoded = layers.LSTM(256, activation='relu', return_sequences=True)(decoder_input)
decoded = layers.LSTM(train_images.shape[2], activation='sigmoid', return_sequences=True)(decoded)

# Create the autoencoder model
autoencoder = models.Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Display a message confirming the autoencoder compilation
print("Autoencoder model compiled successfully.")

# Train: Fit the model on distorted images as input and clear images as target output
# Here we simulate distorted images by adding random noise to the training images
noise_factor = 0.5
train_images_noisy = train_images + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=train_images.shape)
train_images_noisy = np.clip(train_images_noisy, 0., 1.)

# Train the autoencoder
history = autoencoder.fit(train_images_noisy, train_images, epochs=10, batch_size=64, validation_data=(test_images, test_images))

# Verify that the model has been trained successfully
if history.history['loss']:
    print("Autoencoder model trained successfully.")
# Out:
# Training images shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 1)
# Test images shape: (10000, 32, 32, 3)
# Test labels shape: (10000, 1)
# CIFAR-10 dataset loaded successfully.
# CIFAR-10 dataset normalized successfully.
# CIFAR-10 dataset reshaped for LSTM input successfully.
# Encoder model defined successfully.
# Autoencoder model compiled successfully.
# Epoch 1/10
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 71
#      68 train_images_noisy = np.clip(train_images_noisy, 0., 1.)
#      70 # Train the autoencoder
# ---> 71 history = autoencoder.fit(train_images_noisy, train_images, epochs=10, batch_size=64, validation_data=(test_images, test_images))
#      73 # Verify that the model has been trained successfully
#      74 if history.history['loss']:
#
# ...

# %%
# Train: Fit the model on distorted images as input and clear images as target output
# Here we simulate distorted images by adding random noise to the training images
noise_factor = 0.5
train_images_noisy = train_images + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=train_images.shape)
train_images_noisy = np.clip(train_images_noisy, 0., 1.)

# Train the autoencoder
history = autoencoder.fit(train_images_noisy, train_images, epochs=10, batch_size=64, validation_data=(test_images, test_images))

# Verify that the model has been trained successfully
if 'loss' in history.history:
    print("Autoencoder model trained successfully.")
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 8
#       5 train_images_noisy = np.clip(train_images_noisy, 0., 1.)
#       7 # Train the autoencoder
# ----> 8 history = autoencoder.fit(train_images_noisy, train_images, epochs=10, batch_size=64, validation_data=(test_images, test_images))
#      10 # Verify that the model has been trained successfully
#      11 if 'loss' in history.history:
#
# File /opt/anaconda3/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ...

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import layers, models
import numpy as np

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Display the shape of training and testing datasets
print(f"Training images shape: {train_images.shape}")
print(f"Training labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Test labels shape: {test_labels.shape}")

# Verify that the dataset has been loaded successfully
if train_images is not None and train_labels is not None and test_images is not None and test_labels is not None:
    print("CIFAR-10 dataset loaded successfully.")
else:
    print("Failed to load CIFAR-10 dataset.")

# Normalize: Scale pixel values to the range [0, 1]
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# Display a message confirming normalization
print("CIFAR-10 dataset normalized successfully.")

# Reshape: Reshape the images to fit the LSTM model's input requirements
# Typically, LSTMs expect input in the form (samples, time steps, features)
train_images = train_images.reshape((train_images.shape[0], -1, 32 * 3))
test_images = test_images.reshape((test_images.shape[0], -1, 32 * 3))

# Display a message confirming reshaping
print("CIFAR-10 dataset reshaped for LSTM input successfully.")

# Define the encoder part of the autoencoder using LSTM layers
latent_dim = 128

input_layer = layers.Input(shape=(train_images.shape[1], train_images.shape[2]))
encoded = layers.LSTM(256, activation='relu', return_sequences=True)(input_layer)
encoded = layers.LSTM(latent_dim, activation='relu', return_sequences=False)(encoded)

# Create the encoder model
encoder = models.Model(input_layer, encoded)

# Display a message confirming the encoder definition
print("Encoder model defined successfully.")

# Define the decoder part of the autoencoder using LSTM layers
decoder_input = layers.RepeatVector(train_images.shape[1])(encoded)
decoded = layers.LSTM(256, activation='relu', return_sequences=True)(decoder_input)
decoded = layers.LSTM(train_images.shape[2], activation='sigmoid', return_sequences=True)(decoded)

# Create the autoencoder model
autoencoder = models.Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Display a message confirming the autoencoder compilation
print("Autoencoder model compiled successfully.")

# Train: Fit the model on distorted images as input and clear images as target output
# Here we simulate distorted images by adding random noise to the training images
noise_factor = 0.5
train_images_noisy = train_images + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=train_images.shape)
train_images_noisy = np.clip(train_images_noisy, 0., 1.)

# Train the autoencoder
history = autoencoder.fit(train_images_noisy, train_images, epochs=10, batch_size=64, validation_data=(test_images, test_images))

# Verify that the model has been trained successfully
if 'loss' in history.history:
    print("Autoencoder model trained successfully.")
# Out:
# Training images shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 1)
# Test images shape: (10000, 32, 32, 3)
# Test labels shape: (10000, 1)
# CIFAR-10 dataset loaded successfully.
# CIFAR-10 dataset normalized successfully.
# CIFAR-10 dataset reshaped for LSTM input successfully.
# Encoder model defined successfully.
# Autoencoder model compiled successfully.
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 145s 183ms/step - loss: 0.0407 - val_loss: 0.0300
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 140s 179ms/step - loss: 0.0224 - val_loss: 0.0284
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 139s 178ms/step - loss: 0.0194 - val_loss: 0.0268
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 137s 175ms/step - loss: 0.0177 - val_loss: 0.0262
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 142s 181ms/step - loss: 0.0169 - val_loss: 0.0252
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 143s 183ms/step - loss: 0.0162 - val_loss: 0.0270
# Epoch 7/10
# ...

# %%
# Reconstruct: Use the trained model to reconstruct clear images from distorted ones
test_images_noisy = test_images + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=test_images.shape)
test_images_noisy = np.clip(test_images_noisy, 0., 1.)
reconstructed_images = autoencoder.predict(test_images_noisy)

# Visualize: Display the original distorted (blurry) images and the corresponding reconstructed clear images
num_images = 10
plt.figure(figsize=(20, 4))
for i in range(num_images):
    # Display distorted image
    ax = plt.subplot(2, num_images, i + 1)
    plt.imshow(test_images_noisy[i].reshape(32, 32, 3))
    plt.title("Noisy")
    plt.axis("off")

    # Display reconstructed image
    ax = plt.subplot(2, num_images, i + 1 + num_images)
    plt.imshow(reconstructed_images[i].reshape(32, 32, 3))
    plt.title("Reconstructed")
    plt.axis("off")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 8
#       6 # Visualize: Display the original distorted (blurry) images and the corresponding reconstructed clear images
#       7 num_images = 10
# ----> 8 plt.figure(figsize=(20, 4))
#       9 for i in range(num_images):
#      10     # Display distorted image
#      11     ax = plt.subplot(2, num_images, i + 1)
#
# NameError: name 'plt' is not defined

# %%
mport matplotlib.pyplot as plt
# Out:
#   Cell In[39], line 1
#     mport matplotlib.pyplot as plt
#           ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

# %%
# Reconstruct: Use the trained model to reconstruct clear images from distorted ones
test_images_noisy = test_images + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=test_images.shape)
test_images_noisy = np.clip(test_images_noisy, 0., 1.)
reconstructed_images = autoencoder.predict(test_images_noisy)

# Visualize: Display the original distorted (blurry) images and the corresponding reconstructed clear images
num_images = 10
plt.figure(figsize=(20, 4))
for i in range(num_images):
    # Display distorted image
    ax = plt.subplot(2, num_images, i + 1)
    plt.imshow(test_images_noisy[i].reshape(32, 32, 3))
    plt.title("Noisy")
    plt.axis("off")

    # Display reconstructed image
    ax = plt.subplot(2, num_images, i + 1 + num_images)
    plt.imshow(reconstructed_images[i].reshape(32, 32, 3))
    plt.title("Reconstructed")
    plt.axis("off")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step

# %%
# Process a provided blurry image
def process_blurry_image(Users/vuyelwamusinahama/Desktop/INF791 ASS 2/u23911419_Personal _image_Blurruy):
    # Load the image
    img = image.load_img(/Users/vuyelwamusinahama/Desktop/INF791 ASS 2/u23911419_Personal _image_Blurruy, target_size=(32, 32))
    img_array = image.img_to_array(img).astype('float32') / 255.0
    img_array = img_array.reshape(1, -1, 32 * 3)

    # Predict the reconstructed clear image
    reconstructed_img = autoencoder.predict(img_array)

    # Visualize the provided blurry image and the reconstructed clear image
    plt.figure(figsize=(8, 4))
    
    # Display blurry image
    ax = plt.subplot(1, 2, 1)
    plt.imshow(img_array.reshape(32, 32, 3))
    plt.title("Blurry Image")
    plt.axis("off")
    
    # Display reconstructed image
    ax = plt.subplot(1, 2, 2)
    plt.imshow(reconstructed_img.reshape(32, 32, 3))
    plt.title("Reconstructed Image")
    plt.axis("off")
    
    plt.show()
# Out:
#   Cell In[4], line 2
#     def process_blurry_image(Users/vuyelwamusinahama/Desktop/INF791 ASS 2/u23911419_Personal _image_Blurruy):
#                                   ^
# SyntaxError: invalid syntax

# %%
from tensorflow.keras.preprocessing import image

# %%
# Process a provided blurry image
def process_blurry_image(Users/vuyelwamusinahama/Desktop/INF791 ASS 2/u23911419_Personal _image_Blurruy):
    # Load the image
    img = image.load_img(/Users/vuyelwamusinahama/Desktop/INF791 ASS 2/u23911419_Personal _image_Blurruy, target_size=(32, 32))
    img_array = image.img_to_array(img).astype('float32') / 255.0
    img_array = img_array.reshape(1, -1, 32 * 3)

    # Predict the reconstructed clear image
    reconstructed_img = autoencoder.predict(img_array)

    # Visualize the provided blurry image and the reconstructed clear image
    plt.figure(figsize=(8, 4))
    
    # Display blurry image
    ax = plt.subplot(1, 2, 1)
    plt.imshow(img_array.reshape(32, 32, 3))
    plt.title("Blurry Image")
    plt.axis("off")
    
    # Display reconstructed image
    ax = plt.subplot(1, 2, 2)
    plt.imshow(reconstructed_img.reshape(32, 32, 3))
    plt.title("Reconstructed Image")
    plt.axis("off")
    
    plt.show()
# Out:
#   Cell In[8], line 2
#     def process_blurry_image(Users/vuyelwamusinahama/Desktop/INF791 ASS 2/u23911419_Personal _image_Blurruy):
#                                   ^
# SyntaxError: invalid syntax

# %%
# Process a provided blurry image
def process_blurry_image(image_path):
    # Load the image
    img = image.load_img(image_path, target_size=(32, 32))
    img_array = image.img_to_array(img).astype('float32') / 255.0
    img_array = img_array.reshape(1, 32, 32 * 3)

    # Predict the reconstructed clear image
    reconstructed_img = autoencoder.predict(img_array)

    # Visualize the provided blurry image and the reconstructed clear image
    plt.figure(figsize=(8, 4))
    
    # Display blurry image
    ax = plt.subplot(1, 2, 1)
    plt.imshow(img_array.reshape(32, 32, 3))
    plt.title("Blurry Image")
    plt.axis("off")
    
    # Display reconstructed image
    ax = plt.subplot(1, 2, 2)
    plt.imshow(reconstructed_img.reshape(32, 32, 3))
    plt.title("Reconstructed Image")
    plt.axis("off")
    
    plt.show()

process_blurry_image('/Users/vuyelwamusinahama/Desktop/INF791 ASS 2/u23911419_Personal_image_Blurruy.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 28
#      24     plt.axis("off")
#      26     plt.show()
# ---> 28 process_blurry_image('/Users/vuyelwamusinahama/Desktop/INF791 ASS 2/u23911419_Personal_image_Blurruy.jpg')
#
# Cell In[12], line 4, in process_blurry_image(image_path)
#       2 def process_blurry_image(image_path):
#       3     # Load the image
# ----> 4     img = image.load_img(image_path, target_size=(32, 32))
#       5     img_array = image.img_to_array(img).astype('float32') / 255.0
#       6     img_array = img_array.reshape(1, 32, 32 * 3)
#
# File /opt/anaconda3/lib/python3.12/site-packages/keras/src/utils/image_utils.py:235, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     233     if isinstance(path, pathlib.Path):
#     234         path = str(path.resolve())
# --> 235     with open(path, "rb") as f:
# ...

# %%
# Process a provided blurry image
def process_blurry_image(image_path):
    # Load the image
    img = image.load_img(image_path, target_size=(32, 32))
    img_array = image.img_to_array(img).astype('float32') / 255.0
    img_array = img_array.reshape(1, 32, 32 * 3)

    # Predict the reconstructed clear image
    reconstructed_img = autoencoder.predict(img_array)

    # Visualize the provided blurry image and the reconstructed clear image
    plt.figure(figsize=(8, 4))
    
    # Display blurry image
    ax = plt.subplot(1, 2, 1)
    plt.imshow(img_array.reshape(32, 32, 3))
    plt.title("Blurry Image")
    plt.axis("off")
    
    # Display reconstructed image
    ax = plt.subplot(1, 2, 2)
    plt.imshow(reconstructed_img.reshape(32, 32, 3))
    plt.title("Reconstructed Image")
    plt.axis("off")
    
    plt.show()

process_blurry_image('Desktop/INF791 ASS 2/u23911419_Personal_image_Blurruy.jpeg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 28
#      24     plt.axis("off")
#      26     plt.show()
# ---> 28 process_blurry_image('Desktop/INF791 ASS 2/u23911419_Personal_image_Blurruy.jpeg')
#
# Cell In[18], line 4, in process_blurry_image(image_path)
#       2 def process_blurry_image(image_path):
#       3     # Load the image
# ----> 4     img = image.load_img(image_path, target_size=(32, 32))
#       5     img_array = image.img_to_array(img).astype('float32') / 255.0
#       6     img_array = img_array.reshape(1, 32, 32 * 3)
#
# File /opt/anaconda3/lib/python3.12/site-packages/keras/src/utils/image_utils.py:235, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     233     if isinstance(path, pathlib.Path):
#     234         path = str(path.resolve())
# --> 235     with open(path, "rb") as f:
# ...

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Display the shape of training and testing datasets
print(f"Training images shape: {train_images.shape}")
print(f"Training labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Test labels shape: {test_labels.shape}")

# Verify that the dataset has been loaded successfully
if train_images is not None and train_labels is not None and test_images is not None and test_labels is not None:
    print("CIFAR-10 dataset loaded successfully.")
else:
    print("Failed to load CIFAR-10 dataset.")

# Normalize: Scale pixel values to the range [0, 1]
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# Display a message confirming normalization
print("CIFAR-10 dataset normalized successfully.")

# Reshape: Reshape the images to fit the LSTM model's input requirements
# Typically, LSTMs expect input in the form (samples, time steps, features)
train_images = train_images.reshape((train_images.shape[0], -1, 32 * 3))
test_images = test_images.reshape((test_images.shape[0], -1, 32 * 3))

# Display a message confirming reshaping
print("CIFAR-10 dataset reshaped for LSTM input successfully.")

# Define the encoder part of the autoencoder using LSTM layers
latent_dim = 128

input_layer = layers.Input(shape=(train_images.shape[1], train_images.shape[2]))
encoded = layers.LSTM(256, activation='relu', return_sequences=True)(input_layer)
encoded = layers.LSTM(128, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(64, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(32, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(16, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(8, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(latent_dim, activation='relu', return_sequences=False)(encoded)

# Create the encoder model
encoder = models.Model(input_layer, encoded)

# Display a message confirming the encoder definition
print("Encoder model defined successfully.")

# Define the decoder part of the autoencoder using LSTM layers
decoder_input = layers.RepeatVector(train_images.shape[1])(encoded)
decoded = layers.LSTM(256, activation='relu', return_sequences=True)(decoder_input)
decoded = layers.LSTM(train_images.shape[2], activation='sigmoid', return_sequences=True)(decoded)

# Create the autoencoder model
autoencoder = models.Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Display a message confirming the autoencoder compilation
print("Autoencoder model compiled successfully.")

# Train: Fit the model on distorted images as input and clear images as target output
# Here we simulate distorted images by adding random noise to the training images
noise_factor = 0.5
train_images_noisy = train_images + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=train_images.shape)
train_images_noisy = np.clip(train_images_noisy, 0., 1.)

# Train the autoencoder
history = autoencoder.fit(train_images_noisy, train_images, epochs=10, batch_size=64, validation_data=(test_images, test_images))

# Verify that the model has been trained successfully
if 'loss' in history.history:
    print("Autoencoder model trained successfully.")

# Reconstruct: Use the trained model to reconstruct clear images from distorted ones
test_images_noisy = test_images + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=test_images.shape)
test_images_noisy = np.clip(test_images_noisy, 0., 1.)
reconstructed_images = autoencoder.predict(test_images_noisy)

# Visualize: Display the original distorted (blurry) images and the corresponding reconstructed clear images
num_images = 10
plt.figure(figsize=(20, 4))
for i in range(num_images):
    # Display distorted image
    ax = plt.subplot(2, num_images, i + 1)
    plt.imshow(test_images_noisy[i].reshape(32, 32, 3))
    plt.title("Noisy")
    plt.axis("off")

    # Display reconstructed image
    ax = plt.subplot(2, num_images, i + 1 + num_images)
    plt.imshow(reconstructed_images[i].reshape(32, 32, 3))
    plt.title("Reconstructed")
    plt.axis("off")
plt.show()

# Process a provided blurry image
def process_blurry_image(image_path):
    # Load the image
    img = image.load_img(image_path, target_size=(32, 32))
    img_array = image.img_to_array(img).astype('float32') / 255.0
    img_array = img_array.reshape(1, 32, 32 * 3)

    # Predict the reconstructed clear image
    reconstructed_img = autoencoder.predict(img_array)

    # Visualize the provided blurry image and the reconstructed clear image
    plt.figure(figsize=(8, 4))
    
    # Display blurry image
    ax = plt.subplot(1, 2, 1)
    plt.imshow(img_array.reshape(32, 32, 3))
    plt.title("Blurry Image")
    plt.axis("off")
    
    # Display reconstructed image
    ax = plt.subplot(1, 2, 2)
    plt.imshow(reconstructed_img.reshape(32, 32, 3))
    plt.title("Reconstructed Image")
    plt.axis("off")
    
    plt.show()

process_blurry_image('/Users/vuyelwamusinahama/Desktop/INF791 ASS 2/u23911419_Personal_image_Blurry.jpg')
# Out:
# Training images shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 1)
# Test images shape: (10000, 32, 32, 3)
# Test labels shape: (10000, 1)
# CIFAR-10 dataset loaded successfully.
# CIFAR-10 dataset normalized successfully.
# CIFAR-10 dataset reshaped for LSTM input successfully.
# Encoder model defined successfully.
# Autoencoder model compiled successfully.
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 913s 1s/step - loss: 0.0698 - val_loss: 0.0609
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 198s 253ms/step - loss: 0.0684 - val_loss: 0.0764
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 190s 244ms/step - loss: 0.0769 - val_loss: 0.0699
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 200s 256ms/step - loss: 0.0708 - val_loss: 0.0719
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 191s 244ms/step - loss: 0.0717 - val_loss: 0.0719
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 185s 237ms/step - loss: 0.0722 - val_loss: 0.0719
# Epoch 7/10
# ...

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import cv2

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Display the shape of training and testing datasets
print(f"Training images shape: {train_images.shape}")
print(f"Training labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Test labels shape: {test_labels.shape}")

# Verify that the dataset has been loaded successfully
if train_images is not None and train_labels is not None and test_images is not None and test_labels is not None:
    print("CIFAR-10 dataset loaded successfully.")
else:
    print("Failed to load CIFAR-10 dataset.")

# Normalize: Scale pixel values to the range [0, 1]
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# Display a message confirming normalization
print("CIFAR-10 dataset normalized successfully.")

# Create blurred versions of the images using Gaussian Blur
train_images_blurred = np.array([cv2.GaussianBlur(img, (5, 5), 0) for img in train_images])
test_images_blurred = np.array([cv2.GaussianBlur(img, (5, 5), 0) for img in test_images])

# Reshape: Reshape the images to fit the LSTM model's input requirements
# Typically, LSTMs expect input in the form (samples, time steps, features)
train_images = train_images.reshape((train_images.shape[0], -1, 32 * 3))
test_images = test_images.reshape((test_images.shape[0], -1, 32 * 3))
train_images_blurred = train_images_blurred.reshape((train_images_blurred.shape[0], -1, 32 * 3))
test_images_blurred = test_images_blurred.reshape((test_images_blurred.shape[0], -1, 32 * 3))

# Display a message confirming reshaping
print("CIFAR-10 dataset reshaped for LSTM input successfully.")

# Define the encoder part of the autoencoder using LSTM layers
latent_dim = 128

input_layer = layers.Input(shape=(train_images.shape[1], train_images.shape[2]))
encoded = layers.LSTM(256, activation='relu', return_sequences=True)(input_layer)
encoded = layers.LSTM(128, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(64, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(32, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(16, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(8, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(latent_dim, activation='relu', return_sequences=False)(encoded)

# Create the encoder model
encoder = models.Model(input_layer, encoded)

# Display a message confirming the encoder definition
print("Encoder model defined successfully.")

# Define the decoder part of the autoencoder using LSTM layers
decoder_input = layers.RepeatVector(train_images.shape[1])(encoded)
decoded = layers.LSTM(256, activation='relu', return_sequences=True)(decoder_input)
decoded = layers.LSTM(train_images.shape[2], activation='sigmoid', return_sequences=True)(decoded)

# Create the autoencoder model
autoencoder = models.Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Display a message confirming the autoencoder compilation
print("Autoencoder model compiled successfully.")

# Train: Fit the model on blurred images as input and clear images as target output
history = autoencoder.fit(train_images_blurred, train_images, epochs=10, batch_size=51, validation_split=0.2)

# Verify that the model has been trained successfully
if 'loss' in history.history:
    print("Autoencoder model trained successfully.")

# Reconstruct: Use the trained model to reconstruct clear images from blurred ones
test_images_blurred = test_images_blurred.reshape((test_images_blurred.shape[0], -1, 32 * 3))
lstm_reconstructed = autoencoder.predict(test_images_blurred)

# Visualize: Display the original blurred images and the corresponding reconstructed clear images
num_images = 10
plt.figure(figsize=(20, 4))
for i in range(num_images):
    # Display blurred image
    ax = plt.subplot(2, num_images, i + 1)
    plt.imshow(test_images_blurred[i].reshape(32, 32, 3))
    plt.title("Blurred")
    plt.axis("off")

    # Display reconstructed image
    ax = plt.subplot(2, num_images, i + 1 + num_images)
    plt.imshow(lstm_reconstructed[i].reshape(32, 32, 3))
    plt.title("Reconstructed")
    plt.axis("off")
plt.show()

# Process a provided blurry image
def process_blurry_image(image_path):
    # Load the image
    img = image.load_img(image_path, target_size=(32, 32))
    img_array = image.img_to_array(img).astype('float32') / 255.0
    img_array = cv2.GaussianBlur(img_array, (5, 5), 0)  # Apply Gaussian Blur
    img_array = img_array.reshape(1, 32, 32 * 3)

    # Predict the reconstructed clear image
    reconstructed_img = autoencoder.predict(img_array)

    # Visualize the provided blurry image and the reconstructed clear image
    plt.figure(figsize=(8, 4))
    
    # Display blurry image
    ax = plt.subplot(1, 2, 1)
    plt.imshow(img_array.reshape(32, 32, 3))
    plt.title("Blurry Image")
    plt.axis("off")
    
    # Display reconstructed image
    ax = plt.subplot(1, 2, 2)
    plt.imshow(reconstructed_img.reshape(32, 32, 3))
    plt.title("Reconstructed Image")
    plt.axis("off")
    
    plt.show()

process_blurry_image('/Users/vuyelwamusinahama/Desktop/INF791 ASS 2/u23911419_Personal_image_Blurry.jpg')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 7
#       5 import matplotlib.pyplot as plt
#       6 from tensorflow.keras.preprocessing import image
# ----> 7 import cv2
#       9 # Load CIFAR-10 dataset
#      10 (train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
#
# ModuleNotFoundError: No module named 'cv2'

# %%
pip install opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 2.0 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import cv2

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Display the shape of training and testing datasets
print(f"Training images shape: {train_images.shape}")
print(f"Training labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Test labels shape: {test_labels.shape}")

# Verify that the dataset has been loaded successfully
if train_images is not None and train_labels is not None and test_images is not None and test_labels is not None:
    print("CIFAR-10 dataset loaded successfully.")
else:
    print("Failed to load CIFAR-10 dataset.")

# Normalize: Scale pixel values to the range [0, 1]
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# Display a message confirming normalization
print("CIFAR-10 dataset normalized successfully.")

# Create blurred versions of the images using Gaussian Blur
train_images_blurred = np.array([cv2.GaussianBlur(img, (5, 5), 0) for img in train_images])
test_images_blurred = np.array([cv2.GaussianBlur(img, (5, 5), 0) for img in test_images])

# Reshape: Reshape the images to fit the LSTM model's input requirements
# Typically, LSTMs expect input in the form (samples, time steps, features)
train_images = train_images.reshape((train_images.shape[0], -1, 32 * 3))
test_images = test_images.reshape((test_images.shape[0], -1, 32 * 3))
train_images_blurred = train_images_blurred.reshape((train_images_blurred.shape[0], -1, 32 * 3))
test_images_blurred = test_images_blurred.reshape((test_images_blurred.shape[0], -1, 32 * 3))

# Display a message confirming reshaping
print("CIFAR-10 dataset reshaped for LSTM input successfully.")

# Define the encoder part of the autoencoder using LSTM layers
latent_dim = 128

input_layer = layers.Input(shape=(train_images.shape[1], train_images.shape[2]))
encoded = layers.LSTM(256, activation='relu', return_sequences=True)(input_layer)
encoded = layers.LSTM(128, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(64, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(32, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(16, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(8, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(latent_dim, activation='relu', return_sequences=False)(encoded)

# Create the encoder model
encoder = models.Model(input_layer, encoded)

# Display a message confirming the encoder definition
print("Encoder model defined successfully.")

# Define the decoder part of the autoencoder using LSTM layers
decoder_input = layers.RepeatVector(train_images.shape[1])(encoded)
decoded = layers.LSTM(256, activation='relu', return_sequences=True)(decoder_input)
decoded = layers.LSTM(train_images.shape[2], activation='sigmoid', return_sequences=True)(decoded)

# Create the autoencoder model
autoencoder = models.Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Display a message confirming the autoencoder compilation
print("Autoencoder model compiled successfully.")

# Train: Fit the model on blurred images as input and clear images as target output
history = autoencoder.fit(train_images_blurred, train_images, epochs=10, batch_size=51, validation_split=0.2)

# Verify that the model has been trained successfully
if 'loss' in history.history:
    print("Autoencoder model trained successfully.")

# Reconstruct: Use the trained model to reconstruct clear images from blurred ones
test_images_blurred = test_images_blurred.reshape((test_images_blurred.shape[0], -1, 32 * 3))
lstm_reconstructed = autoencoder.predict(test_images_blurred)

# Visualize: Display the original blurred images and the corresponding reconstructed clear images
num_images = 10
plt.figure(figsize=(20, 4))
for i in range(num_images):
    # Display blurred image
    ax = plt.subplot(2, num_images, i + 1)
    plt.imshow(test_images_blurred[i].reshape(32, 32, 3))
    plt.title("Blurred")
    plt.axis("off")

    # Display reconstructed image
    ax = plt.subplot(2, num_images, i + 1 + num_images)
    plt.imshow(lstm_reconstructed[i].reshape(32, 32, 3))
    plt.title("Reconstructed")
    plt.axis("off")
plt.show()

# Process a provided blurry image
def process_blurry_image(image_path):
    # Load the image
    img = image.load_img(image_path, target_size=(32, 32))
    img_array = image.img_to_array(img).astype('float32') / 255.0
    img_array = cv2.GaussianBlur(img_array, (5, 5), 0)  # Apply Gaussian Blur
    img_array = img_array.reshape(1, 32, 32 * 3)

    # Predict the reconstructed clear image
    reconstructed_img = autoencoder.predict(img_array)

    # Visualize the provided blurry image and the reconstructed clear image
    plt.figure(figsize=(8, 4))
    
    # Display blurry image
    ax = plt.subplot(1, 2, 1)
    plt.imshow(img_array.reshape(32, 32, 3))
    plt.title("Blurry Image")
    plt.axis("off")
    
    # Display reconstructed image
    ax = plt.subplot(1, 2, 2)
    plt.imshow(reconstructed_img.reshape(32, 32, 3))
    plt.title("Reconstructed Image")
    plt.axis("off")
    
    plt.show()

process_blurry_image('/Users/vuyelwamusinahama/Desktop/INF791 ASS 2/u23911419_Personal_image_Blurry.jpg')
# Out:
# Training images shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 1)
# Test images shape: (10000, 32, 32, 3)
# Test labels shape: (10000, 1)
# CIFAR-10 dataset loaded successfully.
# CIFAR-10 dataset normalized successfully.
# CIFAR-10 dataset reshaped for LSTM input successfully.
# Encoder model defined successfully.
# Autoencoder model compiled successfully.
# Epoch 1/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 160s 199ms/step - loss: 0.0654 - val_loss: 0.0664
# Epoch 2/10
#  63/785 ━━━━━━━━━━━━━━━━━━━━ 2:19 193ms/step - loss: 0.0656
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 78
#      75 print("Autoencoder model compiled successfully.")
#      77 # Train: Fit the model on blurred images as input and clear images as target output
# ---> 78 history = autoencoder.fit(train_images_blurred, train_images, epochs=10, batch_size=51, validation_split=0.2)
# ...

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import cv2

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Display the shape of training and testing datasets
print(f"Training images shape: {train_images.shape}")
print(f"Training labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Test labels shape: {test_labels.shape}")

# Verify that the dataset has been loaded successfully
if train_images is not None and train_labels is not None and test_images is not None and test_labels is not None:
    print("CIFAR-10 dataset loaded successfully.")
else:
    print("Failed to load CIFAR-10 dataset.")

# Normalize: Scale pixel values to the range [0, 1]
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# Display a message confirming normalization
print("CIFAR-10 dataset normalized successfully.")

# Visualize original images before any modifications
num_images = 10
plt.figure(figsize=(20, 4))
for i in range(num_images):
    ax = plt.subplot(1, num_images, i + 1)
    plt.imshow(train_images[i])
    plt.title("Original")
    plt.axis("off")
plt.show()

# Create blurred versions of the images using Gaussian Blur
train_images_blurred = np.array([cv2.GaussianBlur(img, (5, 5), 0) for img in train_images])
test_images_blurred = np.array([cv2.GaussianBlur(img, (5, 5), 0) for img in test_images])

# Visualize blurred images
plt.figure(figsize=(20, 4))
for i in range(num_images):
    ax = plt.subplot(1, num_images, i + 1)
    plt.imshow(train_images_blurred[i])
    plt.title("Blurred")
    plt.axis("off")
plt.show()

# Reshape: Reshape the images to fit the LSTM model's input requirements
# Typically, LSTMs expect input in the form (samples, time steps, features)
train_images = train_images.reshape((train_images.shape[0], -1, 32 * 3))
test_images = test_images.reshape((test_images.shape[0], -1, 32 * 3))
train_images_blurred = train_images_blurred.reshape((train_images_blurred.shape[0], -1, 32 * 3))
test_images_blurred = test_images_blurred.reshape((test_images_blurred.shape[0], -1, 32 * 3))

# Display a message confirming reshaping
print("CIFAR-10 dataset reshaped for LSTM input successfully.")

# Define the encoder part of the autoencoder using LSTM layers
latent_dim = 128

input_layer = layers.Input(shape=(train_images.shape[1], train_images.shape[2]))
encoded = layers.LSTM(256, activation='relu', return_sequences=True)(input_layer)
encoded = layers.LSTM(128, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(64, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(32, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(16, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(8, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(latent_dim, activation='relu', return_sequences=False)(encoded)

# Create the encoder model
encoder = models.Model(input_layer, encoded)

# Display a message confirming the encoder definition
print("Encoder model defined successfully.")

# Define the decoder part of the autoencoder using LSTM layers
decoder_input = layers.RepeatVector(train_images.shape[1])(encoded)
decoded = layers.LSTM(256, activation='relu', return_sequences=True)(decoder_input)
decoded = layers.LSTM(train_images.shape[2], activation='sigmoid', return_sequences=True)(decoded)

# Create the autoencoder model
autoencoder = models.Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Display a message confirming the autoencoder compilation
print("Autoencoder model compiled successfully.")

# Train: Fit the model on blurred images as input and clear images as target output
history = autoencoder.fit(train_images_blurred, train_images, epochs=10, batch_size=51, validation_split=0.2)

# Verify that the model has been trained successfully
if 'loss' in history.history:
    print("Autoencoder model trained successfully.")

# Reconstruct: Use the trained model to reconstruct clear images from blurred ones
test_images_blurred = test_images_blurred.reshape((test_images_blurred.shape[0], -1, 32 * 3))
lstm_reconstructed = autoencoder.predict(test_images_blurred)

# Visualize: Display the original blurred images and the corresponding reconstructed clear images
plt.figure(figsize=(20, 6))
for i in range(num_images):
    # Display blurred image
    ax = plt.subplot(3, num_images, i + 1)
    plt.imshow(test_images_blurred[i].reshape(32, 32, 3))
    plt.title("Blurred")
    plt.axis("off")

    # Display reconstructed image
    ax = plt.subplot(3, num_images, i + 1 + num_images)
    plt.imshow(lstm_reconstructed[i].reshape(32, 32, 3))
    plt.title("Reconstructed")
    plt.axis("off")

    # Display original image
    ax = plt.subplot(3, num_images, i + 1 + 2 * num_images)
    plt.imshow(test_images[i].reshape(32, 32, 3))
    plt.title("Original")
    plt.axis("off")
plt.show()

# Process a provided blurry image
def process_blurry_image(image_path):
    # Load the image
    img = image.load_img(image_path, target_size=(32, 32))
    img_array = image.img_to_array(img).astype('float32') / 255.0
    img_array = cv2.GaussianBlur(img_array, (5, 5), 0)  # Apply Gaussian Blur
    img_array = img_array.reshape(1, 32, 32 * 3)

    # Predict the reconstructed clear image
    reconstructed_img = autoencoder.predict(img_array)

    # Visualize the provided blurry image and the reconstructed clear image
    plt.figure(figsize=(8, 4))
    
    # Display blurry image
    ax = plt.subplot(1, 2, 1)
    plt.imshow(img_array.reshape(32, 32, 3))
    plt.title("Blurry Image")
    plt.axis("off")
    
    # Display reconstructed image
    ax = plt.subplot(1, 2, 2)
    plt.imshow(reconstructed_img.reshape(32, 32, 3))
    plt.title("Reconstructed Image")
    plt.axis("off")
    
    plt.show()

process_blurry_image('/Users/vuyelwamusinahama/Desktop/INF791 ASS 2/u23911419_Personal_image_Blurry.jpg')
# Out:
# Training images shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 1)
# Test images shape: (10000, 32, 32, 3)
# Test labels shape: (10000, 1)
# CIFAR-10 dataset loaded successfully.
# CIFAR-10 dataset normalized successfully.
# CIFAR-10 dataset reshaped for LSTM input successfully.
# Encoder model defined successfully.
# Autoencoder model compiled successfully.
# Epoch 1/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 155s 193ms/step - loss: 0.0638 - val_loss: 0.0667
# Epoch 2/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 174s 222ms/step - loss: 0.0674 - val_loss: 0.0718
# Epoch 3/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 165s 210ms/step - loss: 0.0719 - val_loss: 0.0723
# Epoch 4/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 166s 211ms/step - loss: 0.0728 - val_loss: 0.0727
# Epoch 5/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 162s 206ms/step - loss: 0.0730 - val_loss: 0.0727
# Epoch 6/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 172s 220ms/step - loss: 0.0731 - val_loss: 0.0727
# Epoch 7/10
# ...

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import cv2

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Display the shape of training and testing datasets
print(f"Training images shape: {train_images.shape}")
print(f"Training labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Test labels shape: {test_labels.shape}")

# Verify that the dataset has been loaded successfully
if train_images is not None and train_labels is not None and test_images is not None and test_labels is not None:
    print("CIFAR-10 dataset loaded successfully.")
else:
    print("Failed to load CIFAR-10 dataset.")

# Normalize: Scale pixel values to the range [0, 1]
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# Display a message confirming normalization
print("CIFAR-10 dataset normalized successfully.")

# Visualize original images before any modifications
num_images = 10
plt.figure(figsize=(20, 4))
for i in range(num_images):
    ax = plt.subplot(1, num_images, i + 1)
    plt.imshow(train_images[i])
    plt.title("Original")
    plt.axis("off")
plt.show()

# Create blurred versions of the images using Gaussian Blur
train_images_blurred = np.array([cv2.GaussianBlur(img, (5, 5), 0) for img in train_images])
test_images_blurred = np.array([cv2.GaussianBlur(img, (5, 5), 0) for img in test_images])

# Visualize blurred images
plt.figure(figsize=(20, 4))
for i in range(num_images):
    ax = plt.subplot(1, num_images, i + 1)
    plt.imshow(train_images_blurred[i])
    plt.title("Blurred")
    plt.axis("off")
plt.show()

# Reshape: Reshape the images to fit the LSTM model's input requirements
# Typically, LSTMs expect input in the form (samples, time steps, features)
train_images = train_images.reshape((train_images.shape[0], -1, 32 * 3))
test_images = test_images.reshape((test_images.shape[0], -1, 32 * 3))
train_images_blurred = train_images_blurred.reshape((train_images_blurred.shape[0], -1, 32 * 3))
test_images_blurred = test_images_blurred.reshape((test_images_blurred.shape[0], -1, 32 * 3))

# Display a message confirming reshaping
print("CIFAR-10 dataset reshaped for LSTM input successfully.")

# Define the encoder part of the autoencoder using LSTM layers
latent_dim = 128

input_layer = layers.Input(shape=(train_images.shape[1], train_images.shape[2]))
encoded = layers.LSTM(256, activation='relu', return_sequences=True)(input_layer)
encoded = layers.LSTM(128, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(64, activation='relu', return_sequences=True)(encoded)
# encoded = layers.LSTM(32, activation='relu', return_sequences=True)(encoded)
# encoded = layers.LSTM(16, activation='relu', return_sequences=True)(encoded)
# encoded = layers.LSTM(8, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(latent_dim, activation='relu', return_sequences=False)(encoded)

# Create the encoder model
encoder = models.Model(input_layer, encoded)

# Display a message confirming the encoder definition
print("Encoder model defined successfully.")

# Define the decoder part of the autoencoder using LSTM layers
decoder_input = layers.RepeatVector(train_images.shape[1])(encoded)
decoded = layers.LSTM(256, activation='relu', return_sequences=True)(decoder_input)
decoded = layers.LSTM(train_images.shape[2], activation='sigmoid', return_sequences=True)(decoded)

# Create the autoencoder model
autoencoder = models.Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Display a message confirming the autoencoder compilation
print("Autoencoder model compiled successfully.")

# Train: Fit the model on blurred images as input and clear images as target output
history = autoencoder.fit(train_images_blurred, train_images, epochs=10, batch_size=51, validation_split=0.2)

# Verify that the model has been trained successfully
if 'loss' in history.history:
    print("Autoencoder model trained successfully.")

# Reconstruct: Use the trained model to reconstruct clear images from blurred ones
test_images_blurred = test_images_blurred.reshape((test_images_blurred.shape[0], -1, 32 * 3))
lstm_reconstructed = autoencoder.predict(test_images_blurred)

# Visualize: Display the original blurred images and the corresponding reconstructed clear images
plt.figure(figsize=(20, 6))
for i in range(num_images):
    # Display blurred image
    ax = plt.subplot(3, num_images, i + 1)
    plt.imshow(test_images_blurred[i].reshape(32, 32, 3))
    plt.title("Blurred")
    plt.axis("off")

    # Display reconstructed image
    ax = plt.subplot(3, num_images, i + 1 + num_images)
    plt.imshow(lstm_reconstructed[i].reshape(32, 32, 3))
    plt.title("Reconstructed")
    plt.axis("off")

    # Display original image
    ax = plt.subplot(3, num_images, i + 1 + 2 * num_images)
    plt.imshow(test_images[i].reshape(32, 32, 3))
    plt.title("Original")
    plt.axis("off")
plt.show()

# Process a provided blurry image
def process_blurry_image(image_path):
    # Load the image
    img = image.load_img(image_path, target_size=(32, 32))
    img_array = image.img_to_array(img).astype('float32') / 255.0
    img_array = cv2.GaussianBlur(img_array, (5, 5), 0)  # Apply Gaussian Blur
    img_array = img_array.reshape(1, 32, 32 * 3)

    # Predict the reconstructed clear image
    reconstructed_img = autoencoder.predict(img_array)

    # Visualize the provided blurry image and the reconstructed clear image
    plt.figure(figsize=(8, 4))
    
    # Display blurry image
    ax = plt.subplot(1, 2, 1)
    plt.imshow(img_array.reshape(32, 32, 3))
    plt.title("Blurry Image")
    plt.axis("off")
    
    # Display reconstructed image
    ax = plt.subplot(1, 2, 2)
    plt.imshow(reconstructed_img.reshape(32, 32, 3))
    plt.title("Reconstructed Image")
    plt.axis("off")
    
    plt.show()

process_blurry_image('/Users/vuyelwamusinahama/Desktop/INF791 ASS 2/u23911419_Personal_image_Blurry.jpg')
# Out:
# Training images shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 1)
# Test images shape: (10000, 32, 32, 3)
# Test labels shape: (10000, 1)
# CIFAR-10 dataset loaded successfully.
# CIFAR-10 dataset normalized successfully.
# CIFAR-10 dataset reshaped for LSTM input successfully.
# Encoder model defined successfully.
# Autoencoder model compiled successfully.
# Epoch 1/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 158s 198ms/step - loss: 0.0834 - val_loss: 0.0683
# Epoch 2/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 163s 207ms/step - loss: 0.0682 - val_loss: 0.0657
# Epoch 3/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 160s 204ms/step - loss: 0.0657 - val_loss: 0.0638
# Epoch 4/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 161s 205ms/step - loss: 0.0654 - val_loss: 0.0665
# Epoch 5/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 162s 206ms/step - loss: 0.0669 - val_loss: 0.0648
# Epoch 6/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 165s 210ms/step - loss: 0.0659 - val_loss: 0.0692
# Epoch 7/10
# ...

# %%
# Plot training and validation loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import cv2
import pandas as pd
import seaborn as sns

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Display the shape of training and testing datasets
print(f"Training images shape: {train_images.shape}")
print(f"Training labels shape: {train_labels.shape}")
print(f"Test images shape: {test_images.shape}")
print(f"Test labels shape: {test_labels.shape}")

# Verify that the dataset has been loaded successfully
if train_images is not None and train_labels is not None and test_images is not None and test_labels is not None:
    print("CIFAR-10 dataset loaded successfully.")
else:
    print("Failed to load CIFAR-10 dataset.")

# Normalize: Scale pixel values to the range [0, 1]
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# Display a message confirming normalization
print("CIFAR-10 dataset normalized successfully.")

# Visualize original images before any modifications
num_images = 10
plt.figure(figsize=(20, 4))
for i in range(num_images):
    ax = plt.subplot(1, num_images, i + 1)
    plt.imshow(train_images[i])
    plt.title("Original")
    plt.axis("off")
plt.show()

# Create blurred versions of the images using Gaussian Blur
train_images_blurred = np.array([cv2.GaussianBlur(img, (5, 5), 0) for img in train_images])
test_images_blurred = np.array([cv2.GaussianBlur(img, (5, 5), 0) for img in test_images])

# Visualize blurred images
plt.figure(figsize=(20, 4))
for i in range(num_images):
    ax = plt.subplot(1, num_images, i + 1)
    plt.imshow(train_images_blurred[i])
    plt.title("Blurred")
    plt.axis("off")
plt.show()

# Reshape: Reshape the images to fit the LSTM model's input requirements
# Typically, LSTMs expect input in the form (samples, time steps, features)
train_images = train_images.reshape((train_images.shape[0], -1, 32 * 3))
test_images = test_images.reshape((test_images.shape[0], -1, 32 * 3))
train_images_blurred = train_images_blurred.reshape((train_images_blurred.shape[0], -1, 32 * 3))
test_images_blurred = test_images_blurred.reshape((test_images_blurred.shape[0], -1, 32 * 3))

# Display a message confirming reshaping
print("CIFAR-10 dataset reshaped for LSTM input successfully.")

# Define the encoder part of the autoencoder using LSTM layers
latent_dim = 128

input_layer = layers.Input(shape=(train_images.shape[1], train_images.shape[2]))
encoded = layers.LSTM(256, activation='relu', return_sequences=True)(input_layer)
encoded = layers.LSTM(128, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(64, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(32, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(16, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(8, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(latent_dim, activation='relu', return_sequences=False)(encoded)

# Create the encoder model
encoder = models.Model(input_layer, encoded)

# Display a message confirming the encoder definition
print("Encoder model defined successfully.")

# Define the decoder part of the autoencoder using LSTM layers
decoder_input = layers.RepeatVector(train_images.shape[1])(encoded)
decoded = layers.LSTM(256, activation='relu', return_sequences=True)(decoder_input)
decoded = layers.LSTM(train_images.shape[2], activation='sigmoid', return_sequences=True)(decoded)

# Create the autoencoder model
autoencoder = models.Model(input_layer, decoded)

# Compile the autoencoder model
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Display a message confirming the autoencoder compilation
print("Autoencoder model compiled successfully.")

# Train: Fit the model on blurred images as input and clear images as target output
history = autoencoder.fit(train_images_blurred, train_images, epochs=10, batch_size=51, validation_split=0.2)

# Verify that the model has been trained successfully
if 'loss' in history.history:
    print("Autoencoder model trained successfully.")

# Reconstruct: Use the trained model to reconstruct clear images from blurred ones
test_images_blurred = test_images_blurred.reshape((test_images_blurred.shape[0], -1, 32 * 3))
lstm_reconstructed = autoencoder.predict(test_images_blurred)

# Visualize: Display the original blurred images and the corresponding reconstructed clear images
plt.figure(figsize=(20, 6))
for i in range(num_images):
    # Display blurred image
    ax = plt.subplot(3, num_images, i + 1)
    plt.imshow(test_images_blurred[i].reshape(32, 32, 3))
    plt.title("Blurred")
    plt.axis("off")

    # Display reconstructed image
    ax = plt.subplot(3, num_images, i + 1 + num_images)
    plt.imshow(lstm_reconstructed[i].reshape(32, 32, 3))
    plt.title("Reconstructed")
    plt.axis("off")

    # Display original image
    ax = plt.subplot(3, num_images, i + 1 + 2 * num_images)
    plt.imshow(test_images[i].reshape(32, 32, 3))
    plt.title("Original")
    plt.axis("off")
plt.show()

# Generate correlation heatmap of latent features
latent_features = encoder.predict(train_images_blurred[:num_images])
latent_df = pd.DataFrame(latent_features)

plt.figure(figsize=(10, 8))
sns.heatmap(latent_df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Latent Features')
plt.show()

# Process a provided blurry image
def process_blurry_image(image_path):
    # Load the image
    img = image.load_img(image_path, target_size=(32, 32))
    img_array = image.img_to_array(img).astype('float32') / 255.0
    img_array = cv2.GaussianBlur(img_array, (5, 5), 0)  # Apply Gaussian Blur
    img_array = img_array.reshape(1, 32, 32 * 3)

    # Predict the reconstructed clear image
    reconstructed_img = autoencoder.predict(img_array)

    # Visualize the provided blurry image and the reconstructed clear image
    plt.figure(figsize=(8, 4))
    
    # Display blurry image
    ax = plt.subplot(1, 2, 1)
    plt.imshow(img_array.reshape(32, 32, 3))
    plt.title("Blurry Image")
    plt.axis("off")
    
    # Display reconstructed image
    ax = plt.subplot(1, 2, 2)
    plt.imshow(reconstructed_img.reshape(32, 32, 3))
    plt.title("Reconstructed Image")
    plt.axis("off")
    
    plt.show()

process_blurry_image('/Users/vuyelwamusinahama/Desktop/INF791 ASS 2/u23911419_Personal_image_Blurry.jpg')
# Out:
# Training images shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 1)
# Test images shape: (10000, 32, 32, 3)
# Test labels shape: (10000, 1)
# CIFAR-10 dataset loaded successfully.
# CIFAR-10 dataset normalized successfully.
# CIFAR-10 dataset reshaped for LSTM input successfully.
# Encoder model defined successfully.
# Autoencoder model compiled successfully.
# Epoch 1/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 167s 208ms/step - loss: 0.0677 - val_loss: 0.0637
# Epoch 2/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 162s 206ms/step - loss: 0.0655 - val_loss: 0.0665
# Epoch 3/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 158s 202ms/step - loss: 0.0668 - val_loss: 0.0660
# Epoch 4/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 158s 201ms/step - loss: 0.0684 - val_loss: 0.0686
# Epoch 5/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 159s 203ms/step - loss: 0.0716 - val_loss: 0.0717
# Epoch 6/10
# 785/785 ━━━━━━━━━━━━━━━━━━━━ 165s 210ms/step - loss: 0.0732 - val_loss: 0.0558
# Epoch 7/10
# ...

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import layers, models
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Normalize: Scale pixel values to the range [0, 1]
train_images = train_images.astype('float32') / 255.0

# Create blurred versions of the images using Gaussian Blur
import cv2
train_images_blurred = np.array([cv2.GaussianBlur(img, (5, 5), 0) for img in train_images])

# Reshape: Reshape the images to fit the LSTM model's input requirements
train_images_blurred = train_images_blurred.reshape((train_images_blurred.shape[0], -1, 32 * 3))

# Define the encoder part of the autoencoder using LSTM layers
latent_dim = 128
input_layer = layers.Input(shape=(train_images_blurred.shape[1], train_images_blurred.shape[2]))
encoded = layers.LSTM(256, activation='relu', return_sequences=True)(input_layer)
encoded = layers.LSTM(128, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(64, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(32, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(16, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(8, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(latent_dim, activation='relu', return_sequences=False)(encoded)

# Create the encoder model
encoder = models.Model(input_layer, encoded)

# Generate correlation heatmap of latent features
latent_features = encoder.predict(train_images_blurred[:100])  # Use a sample of the training data
latent_df = pd.DataFrame(latent_features)

plt.figure(figsize=(10, 8))
sns.heatmap(latent_df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Latent Features')
plt.show()
# Out:
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step WARNING:tensorflow:5 out of the last 318 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x304a8e700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras import layers, models
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import cv2

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Normalize: Scale pixel values to the range [0, 1]
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

# Create blurred versions of the images using Gaussian Blur
train_images_blurred = np.array([cv2.GaussianBlur(img, (5, 5), 0) for img in train_images])

# Reshape: Reshape the images to fit the LSTM model's input requirements
# Typically, LSTMs expect input in the form (samples, time steps, features)
train_images_blurred = train_images_blurred.reshape((train_images_blurred.shape[0], -1, 32 * 3))

# Define the encoder part of the autoencoder using LSTM layers
latent_dim = 128
input_layer = layers.Input(shape=(train_images_blurred.shape[1], train_images_blurred.shape[2]))
encoded = layers.LSTM(256, activation='relu', return_sequences=True)(input_layer)
encoded = layers.LSTM(128, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(64, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(32, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(16, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(8, activation='relu', return_sequences=True)(encoded)
encoded = layers.LSTM(latent_dim, activation='relu', return_sequences=False)(encoded)

# Create the encoder model
encoder = models.Model(input_layer, encoded)

# Generate latent features using the encoder
latent_features = encoder.predict(train_images_blurred[:1000])  # Use a subset for better visualization

# Convert latent features to a DataFrame
latent_df = pd.DataFrame(latent_features)

# Plot correlation heatmap of latent features
plt.figure(figsize=(10, 8))
sns.heatmap(latent_df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Latent Features from LSTM Encoder')
plt.show()
# Out:
# WARNING:tensorflow:6 out of the last 319 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x12ac0fe20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
import numpy as np
import matplotlib.pyplot as plt
import cv2

# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Normalize: Scale pixel values to the range [0, 1]
train_images = train_images.astype('float32') / 255.0

# Create blurred versions of the images using Gaussian Blur
train_images_blurred = np.array([cv2.GaussianBlur(img, (5, 5), 0) for img in train_images])

# Flatten the images for histogram visualization
original_pixels = train_images[:1000].flatten()  # Use a subset for better visualization
blurred_pixels = train_images_blurred[:1000].flatten()

# Plot the pixel value distribution histograms
plt.figure(figsize=(12, 6))
plt.hist(original_pixels, bins=50, alpha=0.5, label='Original', color='blue')
plt.hist(blurred_pixels, bins=50, alpha=0.5, label='Blurred', color='pink')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.title('Pixel Value Distribution for Original and Blurred Images')
plt.legend()
plt.show()
